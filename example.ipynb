# %% [markdown]
# # Hidden Dataset Notebook
#
# Welcome Eneco! We are excited to show the performance of our models on the hidden dataset
#
# All our models are MLP-LSTM Recurrent PPO models that have been trained with the stable_baselines 3 library using our self-made trading gym
#
# All our plots and tables are saved automatically in the /output folder. Please send these results to us so we can see the performance too.
#
# Alternatively you can do a pull request so we can obtain the results

# %% [markdown]
# ## 0. Import and set up

# %% [markdown]
# ### 0.1 Install dependencies

# %%
# %pip install -r requirements.txt
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 0.2 Import packages

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import dill as pickle

from trademodels.dataclasses import OrderType, RLResults
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
#       2 import pandas as pd
# ----> 3 import matplotlib.pyplot as plt
#       4 import dill as pickle
#       6 from trademodels.dataclasses import OrderType, RLResults
#
# ModuleNotFoundError: No module named 'matplotlib'
# Obtaining file:///C:/Users/pelpi/Documents/Repositories/trademodels (from -r requirements.txt (line 1))
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dill==0.3.8 (from -r requirements.txt (line 3))
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#                                               0.0/116.3 kB ? eta -:--:--
#      ------------------------------------   112.6/116.3 kB 3.3 MB/s eta 0:00:01
#      -------------------------------------- 116.3/116.3 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: gymnasium==0.29.1 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 4)) (0.29.1)
# Collecting matplotlib==3.8.2 (from -r requirements.txt (line 5))
#   Downloading matplotlib-3.8.2-cp311-cp311-win_amd64.whl (7.6 MB)
#                                               0.0/7.6 MB ? eta -:--:--
#      -                                        0.2/7.6 MB 5.9 MB/s eta 0:00:02
#      --                                       0.5/7.6 MB 7.0 MB/s eta 0:00:02
#      ---                                      0.7/7.6 MB 7.3 MB/s eta 0:00:01
#      ---                                      0.7/7.6 MB 7.3 MB/s eta 0:00:01
#      ---                                      0.7/7.6 MB 7.3 MB/s eta 0:00:01
#      ------                                   1.2/7.6 MB 5.7 MB/s eta 0:00:02
#      -------                                  1.4/7.6 MB 5.9 MB/s eta 0:00:02
#      -----------                              2.2/7.6 MB 7.9 MB/s eta 0:00:01
#      ------------                             2.4/7.6 MB 7.8 MB/s eta 0:00:01
#      ------------                             2.4/7.6 MB 7.8 MB/s eta 0:00:01
#      -----------------                        3.4/7.6 MB 7.8 MB/s eta 0:00:01
#      -----------------                        3.4/7.6 MB 7.8 MB/s eta 0:00:01
#      ------------------                       3.5/7.6 MB 7.3 MB/s eta 0:00:01
#      ---------------------                    4.2/7.6 MB 7.8 MB/s eta 0:00:01
#      -------------------------                5.0/7.6 MB 8.6 MB/s eta 0:00:01
#      ----------------------------             5.4/7.6 MB 8.9 MB/s eta 0:00:01
#      ----------------------------             5.5/7.6 MB 8.6 MB/s eta 0:00:01
#      ----------------------------------       6.5/7.6 MB 9.5 MB/s eta 0:00:01
#      -------------------------------------    7.1/7.6 MB 9.9 MB/s eta 0:00:01
#      ---------------------------------------- 7.6/7.6 MB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy==1.23.5 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 6)) (1.23.5)
# Collecting pandas==2.2.1 (from -r requirements.txt (line 7))
#   Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
#                                               0.0/11.6 MB ? eta -:--:--
#      -                                        0.3/11.6 MB ? eta -:--:--
#      --                                       0.8/11.6 MB 12.8 MB/s eta 0:00:01
#      ----                                     1.4/11.6 MB 14.9 MB/s eta 0:00:01
#      ------                                   1.9/11.6 MB 13.4 MB/s eta 0:00:01
#      --------                                 2.3/11.6 MB 13.5 MB/s eta 0:00:01
#      ----------                               3.0/11.6 MB 12.0 MB/s eta 0:00:01
#      -----------                              3.4/11.6 MB 12.1 MB/s eta 0:00:01
#      ------------                             3.8/11.6 MB 12.0 MB/s eta 0:00:01
#      --------------                           4.1/11.6 MB 11.3 MB/s eta 0:00:01
#      ----------------                         4.6/11.6 MB 11.4 MB/s eta 0:00:01
#      ----------------                         4.9/11.6 MB 11.6 MB/s eta 0:00:01
downloading jupyter_core-5.7.1-py3-none-any.whl (28 kB)
# Collecting jupyterlab_pygments==0.3.0 (from -r requirements.txt (line 13))
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting jupyterlab_widgets==3.0.10 (from -r requirements.txt (line 14))
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#                                               0.0/215.0 kB ? eta -:--:--
#      ------------------------------------- 215.0/215.0 kB 13.7 MB/s eta 0:00:00
# Collecting ipykernel==6.29.2 (from -r requirements.txt (line 15))
#   Downloading ipykernel-6.29.2-py3-none-any.whl (116 kB)
#                                               0.0/116.1 kB ? eta -:--:--
#      -------------------------------------- 116.1/116.1 kB 6.6 MB/s eta 0:00:00
# Collecting ipython==8.12.3 (from -r requirements.txt (line 16))
#   Downloading ipython-8.12.3-py3-none-any.whl (798 kB)
#                                               0.0/798.3 kB ? eta -:--:--
#      ----                                   102.4/798.3 kB 6.1 MB/s eta 0:00:01
#      ------------------------------------  788.5/798.3 kB 12.6 MB/s eta 0:00:01
#      ------------------------------------- 798.3/798.3 kB 10.1 MB/s eta 0:00:00
# Collecting ipywidgets==8.1.2 (from -r requirements.txt (line 17))
#   Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#                                               0.0/139.4 kB ? eta -:--:--
#      -------------------------------------- 139.4/139.4 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from gymnasium==0.29.1->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from gymnasium==0.29.1->-r requirements.txt (line 4)) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from gymnasium==0.29.1->-r requirements.txt (line 4)) (0.0.4)
# Collecting contourpy>=1.0.1 (from matplotlib==3.8.2->-r requirements.txt (line 5))
#   Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
#                                               0.0/187.6 kB ? eta -:--:--
#      ------------------------------------- 187.6/187.6 kB 11.1 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib==3.8.2->-r requirements.txt (line 5))
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.8.2->-r requirements.txt (line 5))
#   Downloading fonttools-4.49.0-cp311-cp311-win_amd64.whl (2.2 MB)
#                                               0.0/2.2 MB ? eta -:--:--
#      ------                                   0.3/2.2 MB ? eta -:--:--
#      ------------------                       1.0/2.2 MB 20.9 MB/s eta 0:00:01
#      ------------------                       1.0/2.2 MB 16.5 MB/s eta 0:00:01
#      ----------------------------------       1.9/2.2 MB 14.8 MB/s eta 0:00:01
#      ---------------------------------------  2.2/2.2 MB 13.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.2/2.2 MB 12.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib==3.8.2->-r requirements.txt (line 5))
#   Using cached kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.8.2->-r requirements.txt (line 5)) (23.1)
# Collecting pillow>=8 (from matplotlib==3.8.2->-r requirements.txt (line 5))
#   Downloading pillow-10.2.0-cp311-cp311-win_amd64.whl (2.6 MB)
#                                               0.0/2.6 MB ? eta -:--:--
#      --------------                           0.9/2.6 MB 19.8 MB/s eta 0:00:01
#      ----------------------------             1.8/2.6 MB 19.5 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 MB 18.4 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 MB 16.7 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1 (from matplotlib==3.8.2->-r requirements.txt (line 5))
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#                                               0.0/103.2 kB ? eta -:--:--
#      ---------------------------------------- 103.2/103.2 kB ? eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.8.2->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.2.1->-r requirements.txt (line 7)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.2.1->-r requirements.txt (line 7)) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from scikit_learn==1.4.0->-r requirements.txt (line 9)) (1.10.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from scikit_learn==1.4.0->-r requirements.txt (line 9)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from scikit_learn==1.4.0->-r requirements.txt (line 9)) (3.2.0)
# Collecting torch>=1.13 (from stable_baselines3==2.2.1->-r requirements.txt (line 10))
#   Downloading torch-2.2.1-cp311-cp311-win_amd64.whl (198.6 MB)
#                                               0.0/198.6 MB ? eta -:--:--
#                                               0.4/198.6 MB ? eta -:--:--
#                                              1.1/198.6 MB 23.3 MB/s eta 0:00:09
#                                              1.2/198.6 MB 19.8 MB/s eta 0:00:10
#                                              1.3/198.6 MB 10.0 MB/s eta 0:00:20
#                                              2.0/198.6 MB 12.8 MB/s eta 0:00:16
#                                              2.7/198.6 MB 13.3 MB/s eta 0:00:15
#                                              3.0/198.6 MB 13.0 MB/s eta 0:00:16
#                                              3.6/198.6 MB 12.7 MB/s eta 0:00:16
#                                              4.2/198.6 MB 13.4 MB/s eta 0:00:15
#                                              4.4/198.6 MB 12.6 MB/s eta 0:00:16
#      -                                       5.2/198.6 MB 13.2 MB/s eta 0:00:15
#      -                                       5.7/198.6 MB 12.7 MB/s eta 0:00:16
#      -                                       6.4/198.6 MB 12.7 MB/s eta 0:00:16
#      -                                       6.9/198.6 MB 12.7 MB/s eta 0:00:16
#      -                                       7.0/198.6 MB 12.1 MB/s eta 0:00:16
#      -----------------------------          155.4/198.6 MB 8.7 MB/s eta 0:00:05
#      -----------------------------          155.4/198.6 MB 8.7 MB/s eta 0:00:05
#      -----------------------------          156.3/198.6 MB 9.0 MB/s eta 0:00:05
#      -----------------------------          156.4/198.6 MB 8.7 MB/s eta 0:00:05
#      -----------------------------          156.7/198.6 MB 8.8 MB/s eta 0:00:05
#      -----------------------------          156.7/198.6 MB 8.8 MB/s eta 0:00:05
#      ------------------------------         157.3/198.6 MB 9.0 MB/s eta 0:00:05
#      ------------------------------         158.0/198.6 MB 8.6 MB/s eta 0:00:05
#      ------------------------------         158.6/198.6 MB 8.7 MB/s eta 0:00:05
#      ------------------------------         158.9/198.6 MB 8.7 MB/s eta 0:00:05
# ...
#      ----------------------------------    182.5/198.6 MB 10.6 MB/s eta 0:00:02
#      ----------------------------------    183.3/198.6 MB 10.9 MB/s eta 0:00:02
#      ----------------------------------    184.5/198.6 MB 11.7 MB/s eta 0:00:02
#      ----------------------------------    185.5/198.6 MB 11.7 MB/s eta 0:00:02
#      ----------------------------------    185.9/198.6 MB 11.3 MB/s eta 0:00:02
#      ----------------------------------    186.2/198.6 MB 10.9 MB/s eta 0:00:02
#      ----------------------------------    186.2/198.6 MB 10.9 MB/s eta 0:00:02
#      ----------------------------------    186.2/198.6 MB 10.9 MB/s eta 0:00:02
#      ----------------------------------    186.3/198.6 MB 10.2 MB/s eta 0:00:02
#      ----------------------------------    187.3/198.6 MB 10.6 MB/s eta 0:00:02
#      ----------------------------------    187.5/198.6 MB 10.9 MB/s eta 0:00:02
#      ----------------------------------    187.8/198.6 MB 10.2 MB/s eta 0:00:02
#      -----------------------------------   188.2/198.6 MB 10.7 MB/s eta 0:00:01
#      -----------------------------------   188.2/198.6 MB 10.6 MB/s eta 0:00:01
#      -----------------------------------   188.2/198.6 MB 10.6 MB/s eta 0:00:01
#      ------------------------------------   188.9/198.6 MB 9.8 MB/s eta 0:00:01
#      ------------------------------------   189.3/198.6 MB 9.6 MB/s eta 0:00:01
#      ------------------------------------   189.3/198.6 MB 9.6 MB/s eta 0:00:01
#      ------------------------------------   189.3/198.6 MB 9.6 MB/s eta 0:00:01
#      ------------------------------------   190.4/198.6 MB 9.5 MB/s eta 0:00:01
#      ------------------------------------   190.5/198.6 MB 9.2 MB/s eta 0:00:01
#      ------------------------------------   191.1/198.6 MB 9.4 MB/s eta 0:00:01
#      ------------------------------------   191.1/198.6 MB 9.4 MB/s eta 0:00:01
#      ------------------------------------   191.8/198.6 MB 9.1 MB/s eta 0:00:01
#      ------------------------------------   191.8/198.6 MB 9.1 MB/s eta 0:00:01
#      -------------------------------------  193.5/198.6 MB 9.1 MB/s eta 0:00:01
#      -------------------------------------  195.0/198.6 MB 9.6 MB/s eta 0:00:01
#      -------------------------------------  195.4/198.6 MB 9.4 MB/s eta 0:00:01
#      -------------------------------------  196.2/198.6 MB 9.8 MB/s eta 0:00:01
#      ------------------------------------  196.6/198.6 MB 10.7 MB/s eta 0:00:01
#      ------------------------------------  196.7/198.6 MB 10.7 MB/s eta 0:00:01
#      ------------------------------------  197.8/198.6 MB 10.7 MB/s eta 0:00:01
#      ------------------------------------  198.2/198.6 MB 11.1 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 11.9 MB/s eta 0:00:01
#      -------------------------------------- 198.6/198.6 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: pyzmq>=23.0 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from jupyter_client==8.6.0->-r requirements.txt (line 11)) (25.1.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from jupyter_client==8.6.0->-r requirements.txt (line 11)) (6.3.3)
# Requirement already satisfied: traitlets>=5.3 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from jupyter_client==8.6.0->-r requirements.txt (line 11)) (5.10.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from jupyter_core==5.7.1->-r requirements.txt (line 12)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from jupyter_core==5.7.1->-r requirements.txt (line 12)) (306)
# Requirement already satisfied: comm>=0.1.1 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipykernel==6.29.2->-r requirements.txt (line 15)) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipykernel==6.29.2->-r requirements.txt (line 15)) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipykernel==6.29.2->-r requirements.txt (line 15)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipykernel==6.29.2->-r requirements.txt (line 15)) (1.5.8)
# Requirement already satisfied: psutil in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipykernel==6.29.2->-r requirements.txt (line 15)) (5.9.5)
# Requirement already satisfied: backcall in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipython==8.12.3->-r requirements.txt (line 16)) (0.2.0)
# Requirement already satisfied: decorator in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipython==8.12.3->-r requirements.txt (line 16)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipython==8.12.3->-r requirements.txt (line 16)) (0.19.0)
# Requirement already satisfied: pickleshare in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipython==8.12.3->-r requirements.txt (line 16)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipython==8.12.3->-r requirements.txt (line 16)) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipython==8.12.3->-r requirements.txt (line 16)) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipython==8.12.3->-r requirements.txt (line 16)) (0.6.2)
# Requirement already satisfied: colorama in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from ipython==8.12.3->-r requirements.txt (line 16)) (0.4.6)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets==8.1.2->-r requirements.txt (line 17))
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#                                               0.0/2.3 MB ? eta -:--:--
#                                               0.0/2.3 MB ? eta -:--:--
#                                               0.0/2.3 MB ? eta -:--:--
#                                               0.0/2.3 MB ? eta -:--:--
#      ----------------------                   1.3/2.3 MB 40.6 MB/s eta 0:00:01
#      -----------------------------            1.7/2.3 MB 21.9 MB/s eta 0:00:01
#      -------------------------------          1.8/2.3 MB 23.0 MB/s eta 0:00:01
#      ---------------------------------------- 2.3/2.3 MB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.16->ipython==8.12.3->-r requirements.txt (line 16)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython==8.12.3->-r requirements.txt (line 16)) (0.2.6)
# Requirement already satisfied: six>=1.5 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.8.2->-r requirements.txt (line 5)) (1.16.0)
# Collecting filelock (from torch>=1.13->stable_baselines3==2.2.1->-r requirements.txt (line 10))
#   Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium==0.29.1->-r requirements.txt (line 4))
#   Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Collecting sympy (from torch>=1.13->stable_baselines3==2.2.1->-r requirements.txt (line 10))
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#                                               0.0/5.7 MB ? eta -:--:--
#      ---------                                1.3/5.7 MB 13.9 MB/s eta 0:00:01
#      -----------                              1.7/5.7 MB 11.0 MB/s eta 0:00:01
#      -------------                            2.0/5.7 MB 9.8 MB/s eta 0:00:01
#      -----------------                        2.6/5.7 MB 10.9 MB/s eta 0:00:01
#      -----------------                        2.6/5.7 MB 10.9 MB/s eta 0:00:01
#      ------------------------                 3.5/5.7 MB 10.5 MB/s eta 0:00:01
#      -------------------------                3.6/5.7 MB 10.5 MB/s eta 0:00:01
#      ------------------------------           4.4/5.7 MB 11.2 MB/s eta 0:00:01
#      -------------------------------          4.5/5.7 MB 10.6 MB/s eta 0:00:01
#      -------------------------------          4.5/5.7 MB 10.0 MB/s eta 0:00:01
#      -------------------------------------    5.4/5.7 MB 10.7 MB/s eta 0:00:01
#      -------------------------------------    5.4/5.7 MB 10.2 MB/s eta 0:00:01
#      ---------------------------------------  5.7/5.7 MB 9.9 MB/s eta 0:00:01
#      ---------------------------------------- 5.7/5.7 MB 9.4 MB/s eta 0:00:00
# Collecting networkx (from torch>=1.13->stable_baselines3==2.2.1->-r requirements.txt (line 10))
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#                                               0.0/1.6 MB ? eta -:--:--
#      -                                        0.1/1.6 MB ? eta -:--:--
#      ---------------------                    0.9/1.6 MB 14.1 MB/s eta 0:00:01
#      -------------------------                1.0/1.6 MB 11.0 MB/s eta 0:00:01
#      ---------------------------------------- 1.6/1.6 MB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.13->stable_baselines3==2.2.1->-r requirements.txt (line 10)) (3.1.2)
# Collecting fsspec (from torch>=1.13->stable_baselines3==2.2.1->-r requirements.txt (line 10))
#   Downloading fsspec-2024.2.0-py3-none-any.whl (170 kB)
#                                               0.0/170.9 kB ? eta -:--:--
#      ------------------------------------- 170.9/170.9 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: executing>=1.2.0 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython==8.12.3->-r requirements.txt (line 16)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython==8.12.3->-r requirements.txt (line 16)) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython==8.12.3->-r requirements.txt (line 16)) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pelpi\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.13->stable_baselines3==2.2.1->-r requirements.txt (line 10)) (2.1.2)
# Collecting mpmath>=0.19 (from sympy->torch>=1.13->stable_baselines3==2.2.1->-r requirements.txt (line 10))
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#                                               0.0/536.2 kB ? eta -:--:--
#      ------------------------------------- 536.2/536.2 kB 32.9 MB/s eta 0:00:00
# Installing collected packages: mpmath, widgetsnbextension, typing-extensions, sympy, pyparsing, pillow, networkx, kiwisolver, jupyterlab_widgets, jupyterlab_pygments, jupyter_core, fsspec, fonttools, filelock, dill, cycler, contourpy, torch, scikit_learn, pandas, matplotlib, jupyter_client, stable_baselines3, ipython, sb3_contrib, ipywidgets, ipykernel, trademodels
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 4.0.9
#     Uninstalling widgetsnbextension-4.0.9:
#       Successfully uninstalled widgetsnbextension-4.0.9
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: jupyterlab_widgets
#     Found existing installation: jupyterlab-widgets 3.0.9
#     Uninstalling jupyterlab-widgets-3.0.9:
#       Successfully uninstalled jupyterlab-widgets-3.0.9
#   Attempting uninstall: jupyterlab_pygments
#     Found existing installation: jupyterlab-pygments 0.2.2
#     Uninstalling jupyterlab-pygments-0.2.2:
#       Successfully uninstalled jupyterlab-pygments-0.2.2
#   Attempting uninstall: jupyter_core
#     Found existing installation: jupyter_core 5.3.1
#     Uninstalling jupyter_core-5.3.1:
#       Successfully uninstalled jupyter_core-5.3.1
#   Attempting uninstall: scikit_learn
#     Found existing installation: scikit-learn 1.3.1
#     Uninstalling scikit-learn-1.3.1:
#       Successfully uninstalled scikit-learn-1.3.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.1
#     Uninstalling pandas-2.1.1:
#       Successfully uninstalled pandas-2.1.1
#   WARNING: The script isympy.exe is installed in 'c:\Users\pelpi\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-migrate.exe, jupyter-troubleshoot.exe and jupyter.exe are installed in 'c:\Users\pelpi\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\pelpi\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts convert-caffe2-to-onnx.exe, convert-onnx-to-caffe2.exe and torchrun.exe are installed in 'c:\Users\pelpi\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\pelpi\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\~andas.libs\\msvcp140-59fdf63e48138046aebeb6ddb5b4e960.dll'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### 0.3 Create the output directories

# %%
output_dir = "output"

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

result_dir = os.path.join(output_dir, "results")
plots_dir = os.path.join(output_dir, "plots")
agg_dir = os.path.join(plots_dir, "aggresiveness")
vol_dir = os.path.join(plots_dir, "volume")
pnl_dir = os.path.join(plots_dir, "pnl")

# List of directory paths to create
directories = [
    result_dir,
    plots_dir,
    agg_dir,
    vol_dir,
    pnl_dir
]

# Create the directories if they don't exist
for directory in directories:
    if not os.path.exists(directory):
        os.makedirs(directory)

# %% [markdown]
# ## 1. Set up the data
#
# You can store the hidden dataset in the /data directory

# %% [markdown]
# ### 1.1 Load the local data

# %%
# Get the current directory of the notebook
notebook_dir = os.getcwd()

# Construct the path to the data file using a relative path
data_file_name = "" ## FIll in accordingly
data_file_path = os.path.join(notebook_dir, 'data', data_file_name)

# Load the data
raw_data = pd.read_csv(data_file_path)

raw_data.plot(x='from_timestamp', y='open')
raw_data.head()

# %% [markdown]
# ### 1.2 Preprocess the data

# %%
from trademodels.dataclasses import ProcessedData

data = ProcessedData.from_raw_data(raw_data)

# %% [markdown]
# ## 2. Set up our models
#
# We have three models:
# - One that buys every interval
# - One that sells every interval
# - One that chooses whether to buy or sell every interval

# %% [markdown]
# ### 2.1 Set up model parameters

# %%
volume = 20
num_lags = 20
interval_length = 5
cancel_after_one_minute = True
holdable = False

# %% [markdown]
# ### 2.2 Load the models

# %%
from trademodels.model_results.reinforcement_result import RLModelResultAlt

path_to_buy_model = os.path.join("models", "buy_final_model")
path_to_sell_model = os.path.join("models", "sell_final_model")
path_to_both_model = os.path.join("models", "both_final_model")

buy_res = RLModelResultAlt(path_to_buy_model, num_lags, interval_length, volume, always_buy = True, cancel_after_one_minute=cancel_after_one_minute, holdable=holdable)
sell_res = RLModelResultAlt(path_to_sell_model, num_lags, interval_length, volume, always_sell = True, cancel_after_one_minute=cancel_after_one_minute, holdable=holdable)
both_res = RLModelResultAlt(path_to_both_model, num_lags, interval_length, volume, cancel_after_one_minute=cancel_after_one_minute, holdable=holdable)

# %% [markdown]
# ## 3. Obtain the orders put out by the models

# %% [markdown]
# ### 3.1 Go over the hidden dataset and get the results
#
# The results of our model are stored in a custom NamedTuple with these fields
#
# | Type              | Description                                                |
# |-------------------|------------------------------------------------------------|
# | **inserted_orders**        | Orders put out by the model                                 |
# | **executed_limit_orders**          | Limit orders that were executed               |
# | **signal_rewards**     | Signal rewards that the model would have gotten if trained                                    |
# | **execution_rewards**       | Execution rewards that the model would have gotten if trained                            |
# | **execution_rewards_bm** | Execution rewards that the benchmark model would have gotten if trained                            |
# | **benchmark_orders**  | Orders put out by the benchmark model                            |
# | **times**| List of all the times that were a step                          |
#
# WARNING: THIS CAN TAKE SOME TIME (~30 minutes with 30 % of the original data on an AMD 4700U)

# %%
buy_result: RLResults = buy_res.get_output(data)
sell_result: RLResults = sell_res.get_output(data)
both_result: RLResults = both_res.get_output(data)

# %% [markdown]
# ### 3.2 Store the results in a dictionary

# %%
results = {"buy_model": buy_result,
            "sell_model": sell_result,
            "both_model": both_result
           }

# %% [markdown]
# ### 3.3 Save the results

# %%
# Store the results as pickles
for name, result in results.items():
    saving_path = os.path.join(result_dir, name)

    with open(f"{saving_path}.pkl", "wb") as f:
        pickle.dump(result, f)

# %% [markdown]
# ### 3.4 (Optional) Load the results

# %%
names = ["buy_model", "sell_model", "both_model"]

# Dictionary to store loaded results
results = {}

# Load the pickled data
for name in names:
    loading_path = os.path.join(result_dir, name)

    with open(f"{loading_path}.pkl", "rb") as f:
        loaded_result = pickle.load(f)

    results[name] = loaded_result

# %% [markdown]
# ## 4. Evaluate the execution performance

# %% [markdown]
# ### 4.1 Execution reward
#
# There are a lot of intervals where the price doesnt move, so we remove the intervals where the reward is 0

# %%
threshold = -1 #

for name, result in results.items():
    print(name)

    rewards_model = [reward for reward in result.execution_rewards if reward > threshold]
    rewards_bm = [reward for reward in result.execution_rewards_bm if reward > threshold]

    model_descr = pd.Series(rewards_model).describe()
    bm_descr = pd.Series(rewards_bm).describe()

    data_to_put_in_df = {"Model": model_descr,
            "Benchmark": bm_descr}

    df = pd.DataFrame()

    print(df.assign(**data_to_put_in_df))
    print("\n")

# %% [markdown]
# ### 4.2 Aggresiveness
#
# The aggresivness is the amount that orders are put in lower than the best ask for buying, and higher than the best bid for selling

# %%
from trademodels.utils import get_aggresiveness_from_trades, plot_aggresiveness_over_time

agg_dict = {}

for name, result in results.items():
    output = get_aggresiveness_from_trades(result.inserted_orders, data)

    times = [x for x, _ in output]
    agg = [x for _, x in output]

    agg_dict[name] = agg

# %% [markdown]
# #### 4.2.1 Histogram

# %%
for name, agg in agg_dict.items():
    print(name)

    plt.hist(agg, bins=50);
    plt.xlim((0,5))
    plt.xlabel("Aggresiveness (Euros)")
    plt.ylabel("Frequency")

    save_path = os.path.join(agg_dir, f"{name}_hist")
    plt.savefig(save_path)

    plt.show()

# %% [markdown]
# #### 4.2.2 Over time
#
# WARNING: THIS CAN TAKE SOME TIME (~5 minutes with 30% of the original data on an AMD 4700U)

# %%
window_size = 2000

for name, agg in agg_dict.items():
    print(name)

    save_path = os.path.join(agg_dir, f"{name}_time")
    plot_aggresiveness_over_time(times, agg, window_size, save_path)

# %% [markdown]
# ### 4.3 Volume
#
# This is the volume of the trades that are put out by the models

# %% [markdown]
# ### 4.3.1 Volume of executed limit orders

# %%
for name, result in results.items():
    print(name)

    executed_orders_volume = [order.volume for order in result.executed_limit_orders]

    plt.hist(executed_orders_volume, bins=20)
    plt.xlabel("Volume")
    plt.ylabel("Freqency")

    save_path = os.path.join(vol_dir, f"{name}_limit")
    plt.savefig(save_path)

    plt.show()

# %% [markdown]
# ### 4.3.2 Volume of market orders

# %%
for name, result in results.items():
    print(name)

    market_orders_volume = [order.volume for order in result.inserted_orders
                              if str(order.type) == str(OrderType.MARKET_ORDER)]

    plt.hist(market_orders_volume, bins=20)
    plt.xlabel("Volume")
    plt.ylabel("Freqency")

    save_path = os.path.join(vol_dir, f"{name}_market")
    plt.savefig(save_path)

    plt.show()

# %% [markdown]
# ### 4.4 PnL
#
# The PnL indicates the trading performance of the models, the position is liquidated after every interval in our setup

# %%
from trademodels.strategy import StrategyEvaluatorRL

times = data["to_timestamp"]

for name, result in results.items():
    print(name)

    interval_starts = [order.time - pd.Timedelta(minutes=1) for order in result.benchmark_orders ]

    evaluator = StrategyEvaluatorRL(data, interval_starts, result.inserted_orders, interval_length, cancel_after_one_minute)
    evaluator_bm = StrategyEvaluatorRL(data, interval_starts, result.benchmark_orders, interval_length, cancel_after_one_minute)

    pnl_result = evaluator.evaluate(liquidate_after_interval=True)
    pnl_result_bm = evaluator_bm.evaluate(liquidate_after_interval=True)

    plt.plot(times, pnl_result["Portfolio_values"], label='Model')
    plt.plot(times, pnl_result_bm["Portfolio_values"], label='Benchmark')
    plt.xlabel('Time')
    plt.ylabel('Portfolio value')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.legend()

    save_path = os.path.join(pnl_dir, f"{name}")
    plt.savefig(save_path)

    plt.show()
